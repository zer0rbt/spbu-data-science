# %% [markdown]
# Analysing titanic data set (21.09.2024)
#
# link: https://www.kaggle.com/code/adavydenko/titanic-solution-a-beginner-s-guide-russian/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
train = pd.read_csv('C:/Users/zer-oRBT/spbu-data-science/data/titanic/train.csv')
test = pd.read_csv('C:/Users/zer-oRBT/spbu-data-science/data/titanic/test.csv')

# %%
fig = plt.figure(figsize=(12,4))
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)


sns.violinplot(x="Embarked", y="Age", hue="Survived", data=train, split=True, ax=ax1)
sns.violinplot(x="Pclass", y="Age", hue="Survived", data=train, split=True, ax=ax2)
sns.violinplot(x="Sex", y="Age", hue="Survived", data=train, split=True, ax=ax3)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
